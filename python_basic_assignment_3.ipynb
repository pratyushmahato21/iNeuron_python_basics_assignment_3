# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Ans: The advantages of functions are as follows:
#
# a) Reduce duplicacy of code
#
# b) Reusability of code
#
# c) Improving the clarity of code
#
# d) Breaking a complex problem into many small problems
#
# e) Hiding of information

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Ans: The code in a function is run when it is called.

# %% [markdown]
# 3. What statement creates a function?
#
# Ans: def func():
#
#         body of the function

# %% [markdown]
# 4. What is the difference between a function and a function call?
#
# Ans: A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. However the  parameters are not mandatory.
#
# def add(a,b):
#
#     print(a+b)
# This is a function.
#
# Whereas A function call is the code used to pass control to a function.
#
# add(1,2)
#
# This is a function call

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Ans: We can use as many global & local variable as we want

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?
#
# Ans: If the called function is outside the local scope then it will take the value of global variable. If the called function is inside the local scope then it will take the value of local variable unless we have specified globals(variable) inside the local scope

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Ans: Return will display the output only when it is called. Return gives the same output type as it is. Yes it is possible to have a return value in an expression.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Ans: There will be no output to the call of the return value of the function

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# Ans: By using the globals(variable_name) keyword.

# %% [markdown]
# 10. What is the data type of None?
#
# Ans: class NoneType

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Ans: ModuleNotFoundError: No module named 'areallyourpetsnamederic'
#
# There is no module by this name in python

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Ans: spam.bacon(variable)

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Ans: By doing Error handling. Using try, except, else, finally block

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Ans: Try clause is the main program that is to be executed. The purpose of the try block is to run the program. If some error occurs during the execution of try block then it will go to the except block. The purpose of the except block is to stop the code from crashing. We can also use the except block to give the error reason.
